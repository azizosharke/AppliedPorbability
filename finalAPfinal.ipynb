# %% [markdown]
# # Question 2

# %%
import random
random.seed(12345678)
import numpy as np
import matplotlib.pyplot as plt




def cardGame():
    cards = list(range(1, 101))
    random.shuffle(cards)            
    hits = 0
    for x in range(0,100):
        if cards[x] == x+1:
            hits+=1
    return hits 


def main():
    cardSet = np.array([cardGame()for x in range( 10000)])

    variance = np.var(cardSet)
    expectation = np.mean(cardSet)
    print("|The variance of the 10,000 repititions| " + str(variance))
    print("|The expectation of the 10,000 repititions| " + str(expectation))
    plt.plot([cardSet[:i+1].mean() for i in range(10000)])
    plt.plot([cardSet[:i+1].var() for i in range(10000)])
    plt.title("The variance and expectation of 10000 repetitions ")
    main()


    

# plt.get_texts()[0].set_text("Variance")
#  plt.get_texts()[1].set_text("expectation")

# %%
import random
random.seed(12345678)
import numpy as np
import matplotlib.pyplot as plt

def cardGame():
    cards = list(range(1, 101))
    random.shuffle(cards)           
    hits = 0
    for x in range(0,100):
        if cards[x] == x+1:
            hits+=1
    return hits                      


def main():
    cardSet = np.array([cardGame()for x in range( 10000)])

    variance = np.var(cardSet)
    expectation = np.mean(cardSet)
    
    print("|The variance of the 10,000 repititions| " + str(variance))
    print("|The expectation of the 10,000 repititions| " + str(expectation))
    plt.title("The variance and expectation of 10000 repetitions ")
    plt.xlabel(" 10000 simulation ")
    plt.ylabel(" Number of hits   ")

    plt.plot([cardSet[:i+1].var() for i in range(10000)])
    plt.plot([cardSet[:i+1].mean() for i in range(10000)])
    plt.legend(["variance","average"])
    plt.savefig("1stGraph.png")
    plt.show()
    plt.plot(cardSet)
    plt.xlabel(" Number of hits in each game   ")
    plt.show()
 #plt.[0].set_text("number of hits ")
    

    
main()
# Out:
# |The variance of the 10,000 repititions| 1.01039216
# |The expectation of the 10,000 repititions| 1.0028

# %%
import random
random.seed(12345678)
import numpy as np
import matplotlib.pyplot as plt

def cardGame():
    cards = list(range(1, 101))
    random.shuffle(cards)           
    hits = 0
    for x in range(0,100):
        if cards[x] == x+1:
            hits+=1
    return hits                      



cardSet = np.array([cardGame()for x in range(10000)])
variance = np.var(cardSet)
expectation = np.mean(cardSet)
                   
print("|The variance of the 10,000 repititions| " + str(variance))
print("|The expectation of the 10,000 repititions| " + str(expectation))
                   
                   
plt.title("The variance of 10000 repetitions ")
plt.xlabel(" 10000 simulation ")
plt.ylabel(" Number of hits   ")
plt.plot([cardSet[:i+1].var() for i in range(10000)])
plt.legend(["variance"])
plt.savefig("2ndGraph.png")

plt.show()
# Out:
# |The variance of the 10,000 repititions| 1.01039216
# |The expectation of the 10,000 repititions| 1.0028

# %%
import random
random.seed(12345678)
import numpy as np
import matplotlib.pyplot as plt

def cardGame():
    cards = list(range(1, 101))
    random.shuffle(cards)            
    hits = 0
    for x in range(0,100):
        if cards[x] == x+1:
            hits+=1
    return hits                      


def main():
    cardSet = np.array([cardGame()for x in range( 10000)])

    variance = np.var(cardSet)
    expectation = np.mean(cardSet)

    print("|The variance of the 10,000 repititions| " + str(variance))
    print("|The expectation of the 10,000 repititions| " + str(expectation))
    
    plt.title("The expectation of 10000 repetitions ")
    plt.xlabel(" 10000 simulation ")
    plt.ylabel(" Number of hits   ")
    plt.plot([cardSet[:i+1].mean() for i in range(10000)])
    plt.legend(["expectation"])
    plt.savefig("3rdGraph.png")
    plt.show()

    
   
main()
# Out:
# |The variance of the 10,000 repititions| 1.01039216
# |The expectation of the 10,000 repititions| 1.0028
